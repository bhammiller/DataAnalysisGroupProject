# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
# %matplotlib inline
from sklearn.cluster import KMeans

Location="loansmall.csv"
rawdata = pd.read_csv(Location)
workdata=rawdata

# %%
#For remaking the dataframe when I want to start over
workdata=rawdata

# %% [markdown]
# Copied the data into a new dataframe.

# %%
#I use this so I can do a quick check when I want to.
workdata.head()

# %%
#Columns with completely missing data
workdata=workdata.dropna(axis=1,how='all')

#Columns with no variation
workdata=workdata.drop('application_type',axis=1)
workdata=workdata.drop('policy_code',axis=1)

#Columns that are replaced
workdata=workdata.drop('sub_grade',axis=1)
workdata=workdata.drop('home_ownership',axis=1)
workdata=workdata.drop('verification_status',axis=1)
workdata=workdata.drop('loan_status',axis=1)

#Columns with no apparent quantifiable purpose for the type of model I intend
workdata=workdata.drop('url',axis=1)
workdata=workdata.drop('next_pymnt_d',axis=1) #Missing Data
#I do not think that these date fields are useful for developing the model that I want.
workdata=workdata.drop('earliest_cr_line',axis=1) #Missing Data
workdata=workdata.drop('last_pymnt_d',axis=1) #Missing Data
workdata=workdata.drop('last_credit_pull_d',axis=1) #Missing Data

# desc field is too qualitative to work into the type of model I intend
workdata=workdata.drop('desc',axis=1)
workdata=workdata.drop('title',axis=1) #Missing Data
# member_id field seems like it is inapporpriate to use for my analysis
workdata=workdata.drop('member_id',axis=1)
# I am dropping mths_since_last_delinq because it has too many null values for me to feel comfortable with
workdata=workdata.drop('mths_since_last_delinq',axis=1)
# I am cleaning up my rows to remove rows with null data that I feel can not be easily replaced
workdata=workdata.dropna(axis=0,subset=['tot_coll_amt','emp_length','revol_util'])
#Too few values to be significant (more than 30% null)
workdata= workdata.dropna(axis=1,thresh=int(workdata.index.size * .3 ))
'''

workdata=workdata.drop('earliest_cr_line',axis=1)
workdata=workdata.drop('title',axis=1)
'''
# Out:
# "\n\nworkdata=workdata.drop('earliest_cr_line',axis=1)\nworkdata=workdata.drop('title',axis=1)\n"

# %%
#Filling in missing data where I can with appopriate values
workdata['emp_title']=workdata['emp_title'].fillna('unknown')

# %%
workdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144876 entries, 42535 to 194110
# Data columns (total 51 columns):
# id                            144876 non-null int64
# loan_amnt                     144876 non-null int64
# funded_amnt                   144876 non-null int64
# funded_amnt_inv               144876 non-null float64
# term                          144876 non-null int64
# int_rate                      144876 non-null float64
# installment                   144876 non-null float64
# grade                         144876 non-null int64
# emp_title                     144876 non-null object
# emp_length                    144876 non-null float64
# annual_inc                    144876 non-null float64
# issue_d                       144876 non-null object
# pymnt_plan                    144876 non-null int64
# purpose                       144876 non-null object
# zip_code                      144876 non-null object
# addr_state                    144876 non-null object
# dti                           144876 non-null float64
# delinq_2yrs                   144876 non-null float64
# inq_last_6mths                144876 non-null float64
# open_acc                      144876 non-null float64
# pub_rec                       144876 non-null float64
# revol_bal                     144876 non-null int64
# revol_util                    144876 non-null float64
# total_acc                     144876 non-null float64
# initial_list_status           144876 non-null int64
# out_prncp                     144876 non-null float64
# out_prncp_inv                 144876 non-null float64
# total_pymnt                   144876 non-null float64
# total_pymnt_inv               144876 non-null float64
# total_rec_prncp               144876 non-null float64
# total_rec_int                 144876 non-null float64
# total_rec_late_fee            144876 non-null float64
# recoveries                    144876 non-null float64
# collection_recovery_fee       144876 non-null float64
# last_pymnt_amnt               144876 non-null float64
# collections_12_mths_ex_med    144876 non-null float64
# acc_now_delinq                144876 non-null float64
# tot_coll_amt                  144876 non-null float64
# tot_cur_bal                   144876 non-null float64
# total_rev_hi_lim              144876 non-null float64
# home_rent                     144876 non-null int64
# home_mortgage                 144876 non-null int64
# home_none                     144876 non-null int64
# home_other                    144876 non-null int64
# home_own                      144876 non-null int64
# verified                      144876 non-null int64
# not_verified                  144876 non-null int64
# source_verified               144876 non-null int64
# status_charged_off            144876 non-null int64
# status_default                144876 non-null int64
# status_fully_paid             144876 non-null int64
# dtypes: float64(27), int64(19), object(5)
# memory usage: 57.5+ MB

# %%
#Changed term length to a numerical value. Only two possibilities so I used a binary option
def term_to_num(x):
    if x == ' 36 months':
        return 0
    if x == ' 60 months':
        return 1
workdata['term']=rawdata['term'].apply(term_to_num)

def pmnt_plan_to_num(x):
    if x == 'n':
        return 0
    if x == 'y':
        return 1
workdata['pymnt_plan']=rawdata['pymnt_plan'].apply(pmnt_plan_to_num)

def initial_list_status_to_num(x):
    if x == 'f':
        return 0
    if x == 'w':
        return 1
workdata['initial_list_status']=rawdata['initial_list_status'].apply(initial_list_status_to_num)

# %%
#I am using sub grades to get a better spectrum of values.
def grade_to_num(x):
    if x == 'G5':
        return 0
    if x == 'G4':
        return 1
    if x == 'G3':
        return 2
    if x == 'G2':
        return 3
    if x == 'G1':
        return 4
    if x == 'F5':
        return 5
    if x == 'F4':
        return 6
    if x == 'F3':
        return 7
    if x == 'F2':
        return 8
    if x == 'F1':
        return 9
    if x == 'E5':
        return 10
    if x == 'E4':
        return 11
    if x == 'E3':
        return 12
    if x == 'E2':
        return 13
    if x == 'E1':
        return 14
    if x == 'D5':
        return 15
    if x == 'D4':
        return 16
    if x == 'D3':
        return 17
    if x == 'D2':
        return 18
    if x == 'D1':
        return 19
    if x == 'C5':
        return 20
    if x == 'C4':
        return 21
    if x == 'C3':
        return 22
    if x == 'C2':
        return 23
    if x == 'C1':
        return 24
    if x == 'B5':
        return 25
    if x == 'B4':
        return 26
    if x == 'B3':
        return 27
    if x == 'B2':
        return 28
    if x == 'B1':
        return 29
    if x == 'A5':
        return 30
    if x == 'A4':
        return 31
    if x == 'A3':
        return 32
    if x == 'A2':
        return 33
    if x == 'A1':
        return 34

workdata['grade']=rawdata['sub_grade'].apply(grade_to_num)

#Changing employment length to numerical values.
def emp_length_to_num(x):
    if x == '< 1 year':
        return 0
    if x == '1 year':
        return 1
    if x == '2 years':
        return 2
    if x == '3 years':
        return 3
    if x == '4 years':
        return 4
    if x == '5 years':
        return 5
    if x == '6 years':
        return 6
    if x == '7 years':
        return 7
    if x == '8 years':
        return 8
    if x == '9 years':
        return 9
    if x == '10+ years':
        return 10

workdata['emp_length']=rawdata['emp_length'].apply(emp_length_to_num)

# %%
#Home Ownership. I did it this way because I can't see putting levels to this data, so I used dummy columns.
def rent_to_num(x):
    if x == 'RENT':
        return 1
    else:
        return 0

def mortgage_to_num(x):
    if x == 'MORTGAGE':
        return 1
    else:
        return 0
    
def none_to_num(x):
    if x == 'NONE':
        return 1
    else:
        return 0
    
def other_to_num(x):
    if x == 'OTHER':
        return 1
    else:
        return 0
    
def own_to_num(x):
    if x == 'OWN':
        return 1
    else:
        return 0
#expdata=workdata
workdata['home_rent']=rawdata['home_ownership'].apply(rent_to_num)
workdata['home_mortgage']=rawdata['home_ownership'].apply(mortgage_to_num)
workdata['home_none']=rawdata['home_ownership'].apply(none_to_num)
workdata['home_other']=rawdata['home_ownership'].apply(other_to_num)
workdata['home_own']=rawdata['home_ownership'].apply(own_to_num)
#expdata.head()
#workdata['emp_length']

# %%
#Verification Status. I did it this way because I can't see putting levels to this data, so I used dummy columns.
def verified_to_num(x):
    if x == 'Verified':
        return 1
    else:
        return 0

def not_verified_to_num(x):
    if x == 'Not Verified':
        return 1
    else:
        return 0
    
def source_verified_to_num(x):
    if x == 'Source Verified':
        return 1
    else:
        return 0
#expdata=workdata
workdata['verified']=rawdata['verification_status'].apply(verified_to_num)
workdata['not_verified']=rawdata['verification_status'].apply(not_verified_to_num) 
workdata['source_verified']=rawdata['verification_status'].apply(source_verified_to_num)

# %%
#loan Status. I did it this way because I can't see putting levels to this data, so I used dummy columns.
def charged_off_to_num(x):
    if x == 'Charged Off' or x == 'Does not meet the credit policy. Status:Charged Off':
        return 1
    else:
        return 0

def default_to_num(x):
    if x == 'Default' :
        return 1
    else:
        return 0
    
def fully_paid_to_num(x):
    if x == 'Fully Paid' or x == 'Does not meet the credit policy. Status:Fully Paid' :
        return 1
    else:
        return 0

#expdata=workdata
workdata['status_charged_off']=rawdata['loan_status'].apply(charged_off_to_num)
workdata['status_default']=rawdata['loan_status'].apply(default_to_num)
workdata['status_fully_paid']=rawdata['loan_status'].apply(fully_paid_to_num)

# %%
#I am using this for testing what I am doing. It is basically pointless for the overall project
pd.pivot_table(workdata, index= 'initial_list_status', values= "member_id", aggfunc='count', fill_value= 0,
              margins = True, margins_name= 'Total')

# %%
workdata.corr()
# Out:
#                                   id  loan_amnt  funded_amnt  funded_amnt_inv  \
# id                          1.000000  -0.008016    -0.007999        -0.007660
# loan_amnt                  -0.008016   1.000000     0.999994         0.999988
# funded_amnt                -0.007999   0.999994     1.000000         0.999993
# funded_amnt_inv            -0.007660   0.999988     0.999993         1.000000
# term                        0.061890   0.433666     0.433653         0.433636
# int_rate                    0.019009   0.136696     0.136686         0.137086
# installment                -0.021089   0.953050     0.953059         0.953121
# grade                      -0.032228  -0.155441    -0.155428        -0.155825
# emp_length                  0.015342   0.107117     0.107131         0.107076
# annual_inc                 -0.001520   0.350009     0.349996         0.350009
# pymnt_plan                 -0.003260   0.003308     0.003308         0.003296
# dti                        -0.017057   0.045158     0.045151         0.045168
# delinq_2yrs                 0.032212   0.007491     0.007482         0.007529
# inq_last_6mths             -0.016766   0.018162     0.018143         0.018441
# open_acc                    0.002125   0.185906     0.185886         0.185897
# pub_rec                     0.068557  -0.080305    -0.080306        -0.080234
# revol_bal                  -0.025725   0.312283     0.312280         0.312216
# revol_util                 -0.039342   0.099320     0.099319         0.099396
# total_acc                   0.013974   0.230005     0.229985         0.229979
# initial_list_status        -0.006954   0.000515     0.000523         0.000946
# out_prncp                   0.215584   0.429604     0.429612         0.429678
# out_prncp_inv               0.215635   0.429603     0.429611         0.429679
# total_pymnt                -0.128663   0.858627     0.858644         0.858621
# total_pymnt_inv            -0.128339   0.858645     0.858662         0.858652
# total_rec_prncp            -0.131854   0.716878     0.716899         0.716821
# total_rec_int              -0.048055   0.735891     0.735894         0.736017
# total_rec_late_fee         -0.016235   0.060342     0.060345         0.060371
# recoveries                 -0.023450   0.139947     0.139911         0.139947
# collection_recovery_fee    -0.000625   0.098076     0.098076         0.098110
# last_pymnt_amnt            -0.014762   0.342704     0.342715         0.342715
# collections_12_mths_ex_med  0.019730  -0.009830    -0.009829        -0.009812
# acc_now_delinq              0.013921   0.009782     0.009783         0.009774
# tot_coll_amt                0.016064  -0.020593    -0.020592        -0.020607
# tot_cur_bal                 0.004169   0.309403     0.309396         0.309320
# total_rev_hi_lim           -0.009119   0.251179     0.251174         0.251100
# home_rent                  -0.020226  -0.184660    -0.184652        -0.184597
# home_mortgage               0.007077   0.199203     0.199197         0.199129
# home_none                  -0.025533  -0.000043    -0.000043        -0.000035
# home_other                 -0.027654  -0.001577    -0.001577        -0.001592
# home_own                    0.026735  -0.034947    -0.034949        -0.034924
# verified                   -0.059648   0.325190     0.325188         0.325093
# not_verified               -0.076477  -0.398596    -0.398594        -0.398578
# source_verified             0.157786   0.052753     0.052753         0.052850
# status_charged_off         -0.050296   0.020319     0.020298         0.020349
# status_default              0.005522   0.003367     0.003367         0.003388
# status_fully_paid          -0.215350  -0.071449    -0.071441        -0.071529
#
#                                 term  int_rate  installment     grade  \
# id                          0.061890  0.019009    -0.021089 -0.032228
# loan_amnt                   0.433666  0.136696     0.953050 -0.155441
# funded_amnt                 0.433653  0.136686     0.953059 -0.155428
# funded_amnt_inv             0.433636  0.137086     0.953121 -0.155825
# term                        1.000000  0.457692     0.184546 -0.474696
# int_rate                    0.457692  1.000000     0.114511 -0.988745
# installment                 0.184546  0.114511     1.000000 -0.129726
# grade                      -0.474696 -0.988745    -0.129726  1.000000
# emp_length                  0.083272 -0.002171     0.087932  0.000389
# annual_inc                  0.066104 -0.054543     0.351127  0.040424
# pymnt_plan                 -0.001524  0.000774     0.004570 -0.000413
# dti                         0.088544  0.144956     0.038087 -0.136234
# delinq_2yrs                 0.004450  0.083048     0.019069 -0.081496
# inq_last_6mths              0.036945  0.255745     0.042386 -0.260530
# open_acc                    0.070808 -0.013607     0.178872  0.008606
# pub_rec                    -0.022384  0.049786    -0.070823 -0.043861
# revol_bal                   0.090078 -0.030439     0.302631  0.024533
# revol_util                  0.075064  0.339392     0.125825 -0.320491
# total_acc                   0.100964 -0.048902     0.211569  0.039783
# initial_list_status        -0.030078 -0.060338     0.003494  0.056988
# out_prncp                   0.520739  0.206572     0.295455 -0.216913
# out_prncp_inv               0.520704  0.206699     0.295488 -0.217039
# total_pymnt                 0.237340  0.083895     0.867221 -0.097229
# total_pymnt_inv             0.237347  0.084252     0.867294 -0.097585
# total_rec_prncp             0.036019 -0.100278     0.763255  0.091279
# total_rec_int               0.594340  0.472790     0.646927 -0.488527
# total_rec_late_fee          0.017533  0.060183     0.069261 -0.061873
# recoveries                  0.121320  0.144271     0.129494 -0.151318
# collection_recovery_fee     0.080034  0.088274     0.090018 -0.091794
# last_pymnt_amnt             0.151394  0.064514     0.328836 -0.071194
# collections_12_mths_ex_med -0.000554  0.039864    -0.004975 -0.039928
# acc_now_delinq              0.010854  0.037296     0.013103 -0.037751
# tot_coll_amt               -0.003857  0.009482    -0.019518 -0.008601
# tot_cur_bal                 0.114872 -0.145711     0.273606  0.132051
# total_rev_hi_lim            0.055800 -0.155663     0.231297  0.141843
# home_rent                  -0.113899  0.131903    -0.143979 -0.124227
# home_mortgage               0.120179 -0.138338     0.156280  0.129872
# home_none                  -0.003143  0.003483     0.001761 -0.003477
# home_other                 -0.005209  0.003736     0.000822 -0.002420
# home_own                   -0.016123  0.017277    -0.029266 -0.015560
# verified                    0.307232  0.164727     0.276008 -0.169430
# not_verified               -0.385748 -0.194636    -0.336725  0.200408
# source_verified             0.060098  0.018579     0.042998 -0.019350
# status_charged_off          0.070347  0.170126     0.020181 -0.169966
# status_default              0.008241  0.016151     0.002855 -0.015504
# status_fully_paid          -0.170375 -0.105982    -0.030358  0.111231
#
#                             emp_length  annual_inc        ...          \
# id                            0.015342   -0.001520        ...
# loan_amnt                     0.107117    0.350009        ...
# funded_amnt                   0.107131    0.349996        ...
# funded_amnt_inv               0.107076    0.350009        ...
# term                          0.083272    0.066104        ...
# int_rate                     -0.002171   -0.054543        ...
# installment                   0.087932    0.351127        ...
# grade                         0.000389    0.040424        ...
# emp_length                    1.000000    0.059398        ...
# annual_inc                    0.059398    1.000000        ...
# pymnt_plan                   -0.003091   -0.000354        ...
# dti                           0.036229   -0.198594        ...
# delinq_2yrs                   0.025317    0.065021        ...
# inq_last_6mths               -0.009862    0.086994        ...
# open_acc                      0.026136    0.147834        ...
# pub_rec                       0.028288   -0.021951        ...
# revol_bal                     0.083068    0.335742        ...
# revol_util                    0.044651    0.024042        ...
# total_acc                     0.098805    0.223435        ...
# initial_list_status          -0.003471    0.010571        ...
# out_prncp                     0.076490    0.108600        ...
# out_prncp_inv                 0.076479    0.108611        ...
# total_pymnt                   0.084720    0.329485        ...
# total_pymnt_inv               0.084674    0.329504        ...
# total_rec_prncp               0.063809    0.309976        ...
# total_rec_int                 0.091576    0.202141        ...
# total_rec_late_fee           -0.004232    0.023896        ...
# recoveries                    0.007149    0.018418        ...
# collection_recovery_fee       0.011289    0.013662        ...
# last_pymnt_amnt               0.029541    0.152011        ...
# collections_12_mths_ex_med    0.003335    0.003766        ...
# acc_now_delinq                0.006876    0.015077        ...
# tot_coll_amt                  0.003824   -0.001966        ...
# tot_cur_bal                   0.093826    0.485163        ...
# total_rev_hi_lim              0.061913    0.274067        ...
# home_rent                    -0.199338   -0.159903        ...
# home_mortgage                 0.187420    0.178910        ...
# home_none                     0.003801   -0.003543        ...
# home_other                    0.002141   -0.003854        ...
# home_own                      0.012823   -0.041736        ...
# verified                      0.084426    0.069103        ...
# not_verified                 -0.089100   -0.158363        ...
# source_verified              -0.002407    0.093672        ...
# status_charged_off           -0.013477   -0.051482        ...
# status_default                0.004917   -0.004156        ...
# status_fully_paid            -0.030896    0.030653        ...
#
#                             home_mortgage  home_none  home_other  home_own  \
# id                               0.007077  -0.025533   -0.027654  0.026735
# loan_amnt                        0.199203  -0.000043   -0.001577 -0.034947
# funded_amnt                      0.199197  -0.000043   -0.001577 -0.034949
# funded_amnt_inv                  0.199129  -0.000035   -0.001592 -0.034924
# term                             0.120179  -0.003143   -0.005209 -0.016123
# int_rate                        -0.138338   0.003483    0.003736  0.017277
# installment                      0.156280   0.001761    0.000822 -0.029266
# grade                            0.129872  -0.003477   -0.002420 -0.015560
# emp_length                       0.187420   0.003801    0.002141  0.012823
# annual_inc                       0.178910  -0.003543   -0.003854 -0.041736
# pymnt_plan                      -0.002813  -0.000044   -0.000045 -0.000770
# dti                             -0.008648   0.005179    0.008028  0.022645
# delinq_2yrs                      0.047853   0.000723   -0.001088 -0.003540
# inq_last_6mths                   0.092791  -0.005096   -0.002231 -0.007277
# open_acc                         0.134822   0.000772   -0.000825 -0.016330
# pub_rec                         -0.003334  -0.004612   -0.004668 -0.000292
# revol_bal                        0.146312   0.000140   -0.000402 -0.006002
# revol_util                       0.000728   0.003599    0.008702 -0.037361
# total_acc                        0.229550  -0.001998   -0.001352 -0.026512
# initial_list_status              0.004536  -0.004446    0.000894 -0.001478
# out_prncp                        0.100290  -0.006010   -0.006667 -0.009361
# out_prncp_inv                    0.100263  -0.006008   -0.006665 -0.009358
# total_pymnt                      0.166999   0.005701    0.002125 -0.031718
# total_pymnt_inv                  0.166947   0.005708    0.002105 -0.031695
# total_rec_prncp                  0.157468   0.004133    0.001659 -0.028803
# total_rec_int                    0.103353   0.005641    0.001892 -0.022072
# total_rec_late_fee              -0.003554  -0.002054    0.001173  0.002595
# recoveries                       0.001321   0.004697    0.001337 -0.001842
# collection_recovery_fee          0.009735   0.007050   -0.001108 -0.002359
# last_pymnt_amnt                  0.092579   0.000610   -0.003799 -0.014633
# collections_12_mths_ex_med      -0.000814  -0.001005   -0.001017 -0.003124
# acc_now_delinq                   0.011496  -0.000879   -0.000889  0.000258
# tot_coll_amt                     0.006824  -0.000898   -0.001529 -0.002398
# tot_cur_bal                      0.523391  -0.003426   -0.003232 -0.083431
# total_rev_hi_lim                 0.129846  -0.000706   -0.002819  0.006717
# home_rent                       -0.849256  -0.013347   -0.013509 -0.232571
# home_mortgage                    1.000000  -0.018012   -0.018231 -0.313868
# home_none                       -0.018012   1.000000   -0.000287 -0.004933
# home_other                      -0.018231  -0.000287    1.000000 -0.004993
# home_own                        -0.313868  -0.004933   -0.004993  1.000000
# verified                         0.120152   0.002122   -0.000724 -0.021399
# not_verified                    -0.160054   0.002081    0.006173  0.014164
# source_verified                  0.033798  -0.004897   -0.006035  0.010036
# status_charged_off              -0.045494   0.001833    0.004238 -0.000423
# status_default                  -0.010147  -0.000606   -0.000614  0.002926
# status_fully_paid                0.010510   0.011562    0.009422 -0.009673
#
#                             verified  not_verified  source_verified  \
# id                         -0.059648     -0.076477         0.157786
# loan_amnt                   0.325190     -0.398596         0.052753
# funded_amnt                 0.325188     -0.398594         0.052753
# funded_amnt_inv             0.325093     -0.398578         0.052850
# term                        0.307232     -0.385748         0.060098
# int_rate                    0.164727     -0.194636         0.018579
# installment                 0.276008     -0.336725         0.042998
# grade                      -0.169430      0.200408        -0.019350
# emp_length                  0.084426     -0.089100        -0.002407
# annual_inc                  0.069103     -0.158363         0.093672
# pymnt_plan                  0.002770     -0.001756        -0.001386
# dti                         0.184082     -0.155081        -0.049122
# delinq_2yrs                 0.009636     -0.030024         0.021951
# inq_last_6mths              0.043877     -0.067120         0.022050
# open_acc                    0.082731     -0.113716         0.027201
# pub_rec                     0.035564     -0.049972         0.012911
# revol_bal                   0.122634     -0.159914         0.030637
# revol_util                  0.068572     -0.079963         0.006548
# total_acc                   0.122028     -0.173932         0.047063
# initial_list_status        -0.008592      0.010701        -0.001583
# out_prncp                   0.173717     -0.248758         0.068289
# out_prncp_inv               0.173691     -0.248749         0.068310
# total_pymnt                 0.269851     -0.307808         0.018075
# total_pymnt_inv             0.269775     -0.307807         0.018167
# total_rec_prncp             0.197900     -0.222683         0.009838
# total_rec_int               0.296822     -0.346250         0.028477
# total_rec_late_fee          0.018527     -0.026972         0.007778
# recoveries                  0.060324     -0.068883         0.004123
# collection_recovery_fee     0.039468     -0.046388         0.004176
# last_pymnt_amnt             0.113669     -0.135974         0.014685
# collections_12_mths_ex_med  0.031635     -0.039450         0.005886
# acc_now_delinq              0.027274     -0.034213         0.005300
# tot_coll_amt                0.003865     -0.008097         0.004387
# tot_cur_bal                 0.161878     -0.217443         0.047558
# total_rev_hi_lim            0.087386     -0.116228         0.024380
# home_rent                  -0.111285      0.155843        -0.039813
# home_mortgage               0.120152     -0.160054         0.033798
# home_none                   0.002122      0.002081        -0.004897
# home_other                 -0.000724      0.006173        -0.006035
# home_own                   -0.021399      0.014164         0.010036
# verified                    1.000000     -0.633888        -0.500335
# not_verified               -0.633888      1.000000        -0.352499
# source_verified            -0.500335     -0.352499         1.000000
# status_charged_off          0.032950     -0.029516        -0.006825
# status_default              0.003825     -0.002922        -0.001358
# status_fully_paid          -0.050140      0.078559        -0.027278
#
#                             status_charged_off  status_default  \
# id                                   -0.050296        0.005522
# loan_amnt                             0.020319        0.003367
# funded_amnt                           0.020298        0.003367
# funded_amnt_inv                       0.020349        0.003388
# term                                  0.070347        0.008241
# int_rate                              0.170126        0.016151
# installment                           0.020181        0.002855
# grade                                -0.169966       -0.015504
# emp_length                           -0.013477        0.004917
# annual_inc                           -0.051482       -0.004156
# pymnt_plan                           -0.000933       -0.000095
# dti                                   0.071881        0.001172
# delinq_2yrs                          -0.001645        0.001543
# inq_last_6mths                        0.060933        0.005902
# open_acc                              0.007750        0.002604
# pub_rec                              -0.005080        0.002830
# revol_bal                            -0.017022       -0.002145
# revol_util                            0.048188        0.002211
# total_acc                            -0.014344       -0.003647
# initial_list_status                  -0.013975       -0.001034
# out_prncp                            -0.192975        0.040323
# out_prncp_inv                        -0.192963        0.040335
# total_pymnt                          -0.262434       -0.008613
# total_pymnt_inv                      -0.262383       -0.008596
# total_rec_prncp                      -0.336368       -0.015963
# total_rec_int                        -0.058475        0.015930
# total_rec_late_fee                    0.102237        0.026277
# recoveries                            0.542439       -0.006944
# collection_recovery_fee               0.354864       -0.004543
# last_pymnt_amnt                      -0.201101       -0.020416
# collections_12_mths_ex_med            0.001756        0.000763
# acc_now_delinq                        0.006110        0.001036
# tot_coll_amt                         -0.004753       -0.000655
# tot_cur_bal                          -0.054777       -0.009312
# total_rev_hi_lim                     -0.033223       -0.002930
# home_rent                             0.046634        0.008816
# home_mortgage                        -0.045494       -0.010147
# home_none                             0.001833       -0.000606
# home_other                            0.004238       -0.000614
# home_own                             -0.000423        0.002926
# verified                              0.032950        0.003825
# not_verified                         -0.029516       -0.002922
# source_verified                      -0.006825       -0.001358
# status_charged_off                    1.000000       -0.012801
# status_default                       -0.012801        1.000000
# status_fully_paid                    -0.329257       -0.033420
#
#                             status_fully_paid
# id                                  -0.215350
# loan_amnt                           -0.071449
# funded_amnt                         -0.071441
# funded_amnt_inv                     -0.071529
# term                                -0.170375
# int_rate                            -0.105982
# installment                         -0.030358
# grade                                0.111231
# emp_length                          -0.030896
# annual_inc                           0.030653
# pymnt_plan                          -0.002436
# dti                                 -0.080763
# delinq_2yrs                         -0.009960
# inq_last_6mths                       0.035517
# open_acc                            -0.014362
# pub_rec                              0.005880
# revol_bal                           -0.024335
# revol_util                          -0.071767
# total_acc                            0.045140
# initial_list_status                  0.008801
# out_prncp                           -0.503806
# out_prncp_inv                       -0.503776
# total_pymnt                          0.244574
# total_pymnt_inv                      0.244466
# total_rec_prncp                      0.402878
# total_rec_int                       -0.243366
# total_rec_late_fee                  -0.071556
# recoveries                          -0.178602
# collection_recovery_fee             -0.116841
# last_pymnt_amnt                      0.614301
# collections_12_mths_ex_med           0.000206
# acc_now_delinq                      -0.009639
# tot_coll_amt                         0.004432
# tot_cur_bal                          0.025108
# total_rev_hi_lim                    -0.002855
# home_rent                           -0.006133
# home_mortgage                        0.010510
# home_none                            0.011562
# home_other                           0.009422
# home_own                            -0.009673
# verified                            -0.050140
# not_verified                         0.078559
# source_verified                     -0.027278
# status_charged_off                  -0.329257
# status_default                      -0.033420
# status_fully_paid                    1.000000
#
# [46 rows x 46 columns]

# %%
#Going to run a regression analysis to determine fully_paid_status of a loan
result = sm.ols(formula='status_fully_paid ~ out_prncp + out_prncp_inv + total_rec_prncp + last_pymnt_amnt + status_charged_off -1', data=workdata).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      status_fully_paid   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                 5.553e+04
# Date:                Fri, 26 Oct 2018   Prob (F-statistic):               0.00
# Time:                        00:19:44   Log-Likelihood:                -72135.
# No. Observations:              144876   AIC:                         1.443e+05
# Df Residuals:                  144871   BIC:                         1.443e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# out_prncp             -0.0010      0.000     -6.396      0.000      -0.001      -0.001
# out_prncp_inv          0.0009      0.000      6.214      0.000       0.001       0.001
# total_rec_prncp     2.914e-05   1.45e-07    201.514      0.000    2.89e-05    2.94e-05
# last_pymnt_amnt     3.157e-05   2.51e-07    125.855      0.000    3.11e-05    3.21e-05
# status_charged_off    -0.1328      0.003    -41.975      0.000      -0.139      -0.127
# ==============================================================================
# Omnibus:                     1055.086   Durbin-Watson:                   1.740
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              899.103
# Skew:                           0.136   Prob(JB):                    5.79e-196
# Kurtosis:                       2.726   Cond. No.                     4.42e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# I am going to try to narrow the database down to what would be known at the signing of a loan contract
startdata=workdata
startdata=startdata.drop('out_prncp',axis=1)
startdata=startdata.drop('out_prncp_inv',axis=1)
startdata=startdata.drop('total_pymnt',axis=1)
startdata=startdata.drop('total_pymnt_inv',axis=1)
startdata=startdata.drop('total_rec_prncp',axis=1)
startdata=startdata.drop('total_rec_int',axis=1)
startdata=startdata.drop('total_rec_late_fee',axis=1)
startdata=startdata.drop('last_pymnt_amnt',axis=1)

# %%
fullypaidgdata=startdata.select_dtypes(exclude=['object']) 
fullypaidgdata=fullypaidgdata.drop('status_default',axis=1)
fullypaidgdata=fullypaidgdata.drop('status_charged_off',axis=1)
X = fullypaidgdata.drop('status_fully_paid', axis = 1)
lm.fit(X, fullypaidgdata.status_fully_paid)
print('Estimated intercept coefficent:',lm.intercept_)
print('Number of coefficients:',len(lm.coef_))
print('R^2:', lm.score(X, fullypaidgdata.status_fully_paid))
# Out:
# Estimated intercept coefficent: 0.6785579680848782
# Number of coefficients: 35
# R^2: 0.11979421006532665

# %%
import sklearn
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, fullypaidgdata.status_fully_paid
                                                                           ,test_size=0.33, random_state=5)

# %%
lm=LinearRegression()
lm.fit(X_train, Y_train)
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)

# %%
#Trying to determine Chance of default
defaultingdata=startdata.select_dtypes(exclude=['object']) 
defaultingdata=defaultingdata.drop('status_charged_off',axis=1)
defaultingdata=defaultingdata.drop('status_fully_paid',axis=1)

# %%
defaultingdata.corr()
# Out:
#                                   id  loan_amnt  funded_amnt  funded_amnt_inv  \
# id                          1.000000  -0.008016    -0.007999        -0.007660
# loan_amnt                  -0.008016   1.000000     0.999994         0.999988
# funded_amnt                -0.007999   0.999994     1.000000         0.999993
# funded_amnt_inv            -0.007660   0.999988     0.999993         1.000000
# term                        0.061890   0.433666     0.433653         0.433636
# int_rate                    0.019009   0.136696     0.136686         0.137086
# installment                -0.021089   0.953050     0.953059         0.953121
# grade                      -0.032228  -0.155441    -0.155428        -0.155825
# emp_length                  0.015342   0.107117     0.107131         0.107076
# annual_inc                 -0.001520   0.350009     0.349996         0.350009
# pymnt_plan                 -0.003260   0.003308     0.003308         0.003296
# dti                        -0.017057   0.045158     0.045151         0.045168
# delinq_2yrs                 0.032212   0.007491     0.007482         0.007529
# inq_last_6mths             -0.016766   0.018162     0.018143         0.018441
# open_acc                    0.002125   0.185906     0.185886         0.185897
# pub_rec                     0.068557  -0.080305    -0.080306        -0.080234
# revol_bal                  -0.025725   0.312283     0.312280         0.312216
# revol_util                 -0.039342   0.099320     0.099319         0.099396
# total_acc                   0.013974   0.230005     0.229985         0.229979
# initial_list_status        -0.006954   0.000515     0.000523         0.000946
# recoveries                 -0.023450   0.139947     0.139911         0.139947
# collection_recovery_fee    -0.000625   0.098076     0.098076         0.098110
# collections_12_mths_ex_med  0.019730  -0.009830    -0.009829        -0.009812
# acc_now_delinq              0.013921   0.009782     0.009783         0.009774
# tot_coll_amt                0.016064  -0.020593    -0.020592        -0.020607
# tot_cur_bal                 0.004169   0.309403     0.309396         0.309320
# total_rev_hi_lim           -0.009119   0.251179     0.251174         0.251100
# home_rent                  -0.020226  -0.184660    -0.184652        -0.184597
# home_mortgage               0.007077   0.199203     0.199197         0.199129
# home_none                  -0.025533  -0.000043    -0.000043        -0.000035
# home_other                 -0.027654  -0.001577    -0.001577        -0.001592
# home_own                    0.026735  -0.034947    -0.034949        -0.034924
# verified                   -0.059648   0.325190     0.325188         0.325093
# not_verified               -0.076477  -0.398596    -0.398594        -0.398578
# source_verified             0.157786   0.052753     0.052753         0.052850
# status_default              0.005522   0.003367     0.003367         0.003388
#
#                                 term  int_rate  installment     grade  \
# id                          0.061890  0.019009    -0.021089 -0.032228
# loan_amnt                   0.433666  0.136696     0.953050 -0.155441
# funded_amnt                 0.433653  0.136686     0.953059 -0.155428
# funded_amnt_inv             0.433636  0.137086     0.953121 -0.155825
# term                        1.000000  0.457692     0.184546 -0.474696
# int_rate                    0.457692  1.000000     0.114511 -0.988745
# installment                 0.184546  0.114511     1.000000 -0.129726
# grade                      -0.474696 -0.988745    -0.129726  1.000000
# emp_length                  0.083272 -0.002171     0.087932  0.000389
# annual_inc                  0.066104 -0.054543     0.351127  0.040424
# pymnt_plan                 -0.001524  0.000774     0.004570 -0.000413
# dti                         0.088544  0.144956     0.038087 -0.136234
# delinq_2yrs                 0.004450  0.083048     0.019069 -0.081496
# inq_last_6mths              0.036945  0.255745     0.042386 -0.260530
# open_acc                    0.070808 -0.013607     0.178872  0.008606
# pub_rec                    -0.022384  0.049786    -0.070823 -0.043861
# revol_bal                   0.090078 -0.030439     0.302631  0.024533
# revol_util                  0.075064  0.339392     0.125825 -0.320491
# total_acc                   0.100964 -0.048902     0.211569  0.039783
# initial_list_status        -0.030078 -0.060338     0.003494  0.056988
# recoveries                  0.121320  0.144271     0.129494 -0.151318
# collection_recovery_fee     0.080034  0.088274     0.090018 -0.091794
# collections_12_mths_ex_med -0.000554  0.039864    -0.004975 -0.039928
# acc_now_delinq              0.010854  0.037296     0.013103 -0.037751
# tot_coll_amt               -0.003857  0.009482    -0.019518 -0.008601
# tot_cur_bal                 0.114872 -0.145711     0.273606  0.132051
# total_rev_hi_lim            0.055800 -0.155663     0.231297  0.141843
# home_rent                  -0.113899  0.131903    -0.143979 -0.124227
# home_mortgage               0.120179 -0.138338     0.156280  0.129872
# home_none                  -0.003143  0.003483     0.001761 -0.003477
# home_other                 -0.005209  0.003736     0.000822 -0.002420
# home_own                   -0.016123  0.017277    -0.029266 -0.015560
# verified                    0.307232  0.164727     0.276008 -0.169430
# not_verified               -0.385748 -0.194636    -0.336725  0.200408
# source_verified             0.060098  0.018579     0.042998 -0.019350
# status_default              0.008241  0.016151     0.002855 -0.015504
#
#                             emp_length  annual_inc       ...        \
# id                            0.015342   -0.001520       ...
# loan_amnt                     0.107117    0.350009       ...
# funded_amnt                   0.107131    0.349996       ...
# funded_amnt_inv               0.107076    0.350009       ...
# term                          0.083272    0.066104       ...
# int_rate                     -0.002171   -0.054543       ...
# installment                   0.087932    0.351127       ...
# grade                         0.000389    0.040424       ...
# emp_length                    1.000000    0.059398       ...
# annual_inc                    0.059398    1.000000       ...
# pymnt_plan                   -0.003091   -0.000354       ...
# dti                           0.036229   -0.198594       ...
# delinq_2yrs                   0.025317    0.065021       ...
# inq_last_6mths               -0.009862    0.086994       ...
# open_acc                      0.026136    0.147834       ...
# pub_rec                       0.028288   -0.021951       ...
# revol_bal                     0.083068    0.335742       ...
# revol_util                    0.044651    0.024042       ...
# total_acc                     0.098805    0.223435       ...
# initial_list_status          -0.003471    0.010571       ...
# recoveries                    0.007149    0.018418       ...
# collection_recovery_fee       0.011289    0.013662       ...
# collections_12_mths_ex_med    0.003335    0.003766       ...
# acc_now_delinq                0.006876    0.015077       ...
# tot_coll_amt                  0.003824   -0.001966       ...
# tot_cur_bal                   0.093826    0.485163       ...
# total_rev_hi_lim              0.061913    0.274067       ...
# home_rent                    -0.199338   -0.159903       ...
# home_mortgage                 0.187420    0.178910       ...
# home_none                     0.003801   -0.003543       ...
# home_other                    0.002141   -0.003854       ...
# home_own                      0.012823   -0.041736       ...
# verified                      0.084426    0.069103       ...
# not_verified                 -0.089100   -0.158363       ...
# source_verified              -0.002407    0.093672       ...
# status_default                0.004917   -0.004156       ...
#
#                             total_rev_hi_lim  home_rent  home_mortgage  \
# id                                 -0.009119  -0.020226       0.007077
# loan_amnt                           0.251179  -0.184660       0.199203
# funded_amnt                         0.251174  -0.184652       0.199197
# funded_amnt_inv                     0.251100  -0.184597       0.199129
# term                                0.055800  -0.113899       0.120179
# int_rate                           -0.155663   0.131903      -0.138338
# installment                         0.231297  -0.143979       0.156280
# grade                               0.141843  -0.124227       0.129872
# emp_length                          0.061913  -0.199338       0.187420
# annual_inc                          0.274067  -0.159903       0.178910
# pymnt_plan                         -0.000805   0.003312      -0.002813
# dti                                 0.052605  -0.004156      -0.008648
# delinq_2yrs                        -0.026017  -0.047052       0.047853
# inq_last_6mths                      0.033734  -0.090780       0.092791
# open_acc                            0.256014  -0.129075       0.134822
# pub_rec                            -0.073084   0.003900      -0.003334
# revol_bal                           0.803925  -0.146568       0.146312
# revol_util                         -0.137210   0.019542       0.000728
# total_acc                           0.216077  -0.220370       0.229550
# initial_list_status                 0.011375  -0.003706       0.004536
# recoveries                          0.007635  -0.000542       0.001321
# collection_recovery_fee             0.008393  -0.008871       0.009735
# collections_12_mths_ex_med         -0.003820   0.002637      -0.000814
# acc_now_delinq                      0.009034  -0.011859       0.011496
# tot_coll_amt                       -0.017333  -0.005577       0.006824
# tot_cur_bal                         0.341045  -0.489749       0.523391
# total_rev_hi_lim                    1.000000  -0.136636       0.129846
# home_rent                          -0.136636   1.000000      -0.849256
# home_mortgage                       0.129846  -0.849256       1.000000
# home_none                          -0.000706  -0.013347      -0.018012
# home_other                         -0.002819  -0.013509      -0.018231
# home_own                            0.006717  -0.232571      -0.313868
# verified                            0.087386  -0.111285       0.120152
# not_verified                       -0.116228   0.155843      -0.160054
# source_verified                     0.024380  -0.039813       0.033798
# status_default                     -0.002930   0.008816      -0.010147
#
#                             home_none  home_other  home_own  verified  \
# id                          -0.025533   -0.027654  0.026735 -0.059648
# loan_amnt                   -0.000043   -0.001577 -0.034947  0.325190
# funded_amnt                 -0.000043   -0.001577 -0.034949  0.325188
# funded_amnt_inv             -0.000035   -0.001592 -0.034924  0.325093
# term                        -0.003143   -0.005209 -0.016123  0.307232
# int_rate                     0.003483    0.003736  0.017277  0.164727
# installment                  0.001761    0.000822 -0.029266  0.276008
# grade                       -0.003477   -0.002420 -0.015560 -0.169430
# emp_length                   0.003801    0.002141  0.012823  0.084426
# annual_inc                  -0.003543   -0.003854 -0.041736  0.069103
# pymnt_plan                  -0.000044   -0.000045 -0.000770  0.002770
# dti                          0.005179    0.008028  0.022645  0.184082
# delinq_2yrs                  0.000723   -0.001088 -0.003540  0.009636
# inq_last_6mths              -0.005096   -0.002231 -0.007277  0.043877
# open_acc                     0.000772   -0.000825 -0.016330  0.082731
# pub_rec                     -0.004612   -0.004668 -0.000292  0.035564
# revol_bal                    0.000140   -0.000402 -0.006002  0.122634
# revol_util                   0.003599    0.008702 -0.037361  0.068572
# total_acc                   -0.001998   -0.001352 -0.026512  0.122028
# initial_list_status         -0.004446    0.000894 -0.001478 -0.008592
# recoveries                   0.004697    0.001337 -0.001842  0.060324
# collection_recovery_fee      0.007050   -0.001108 -0.002359  0.039468
# collections_12_mths_ex_med  -0.001005   -0.001017 -0.003124  0.031635
# acc_now_delinq              -0.000879   -0.000889  0.000258  0.027274
# tot_coll_amt                -0.000898   -0.001529 -0.002398  0.003865
# tot_cur_bal                 -0.003426   -0.003232 -0.083431  0.161878
# total_rev_hi_lim            -0.000706   -0.002819  0.006717  0.087386
# home_rent                   -0.013347   -0.013509 -0.232571 -0.111285
# home_mortgage               -0.018012   -0.018231 -0.313868  0.120152
# home_none                    1.000000   -0.000287 -0.004933  0.002122
# home_other                  -0.000287    1.000000 -0.004993 -0.000724
# home_own                    -0.004933   -0.004993  1.000000 -0.021399
# verified                     0.002122   -0.000724 -0.021399  1.000000
# not_verified                 0.002081    0.006173  0.014164 -0.633888
# source_verified             -0.004897   -0.006035  0.010036 -0.500335
# status_default              -0.000606   -0.000614  0.002926  0.003825
#
#                             not_verified  source_verified  status_default
# id                             -0.076477         0.157786        0.005522
# loan_amnt                      -0.398596         0.052753        0.003367
# funded_amnt                    -0.398594         0.052753        0.003367
# funded_amnt_inv                -0.398578         0.052850        0.003388
# term                           -0.385748         0.060098        0.008241
# int_rate                       -0.194636         0.018579        0.016151
# installment                    -0.336725         0.042998        0.002855
# grade                           0.200408        -0.019350       -0.015504
# emp_length                     -0.089100        -0.002407        0.004917
# annual_inc                     -0.158363         0.093672       -0.004156
# pymnt_plan                     -0.001756        -0.001386       -0.000095
# dti                            -0.155081        -0.049122        0.001172
# delinq_2yrs                    -0.030024         0.021951        0.001543
# inq_last_6mths                 -0.067120         0.022050        0.005902
# open_acc                       -0.113716         0.027201        0.002604
# pub_rec                        -0.049972         0.012911        0.002830
# revol_bal                      -0.159914         0.030637       -0.002145
# revol_util                     -0.079963         0.006548        0.002211
# total_acc                      -0.173932         0.047063       -0.003647
# initial_list_status             0.010701        -0.001583       -0.001034
# recoveries                     -0.068883         0.004123       -0.006944
# collection_recovery_fee        -0.046388         0.004176       -0.004543
# collections_12_mths_ex_med     -0.039450         0.005886        0.000763
# acc_now_delinq                 -0.034213         0.005300        0.001036
# tot_coll_amt                   -0.008097         0.004387       -0.000655
# tot_cur_bal                    -0.217443         0.047558       -0.009312
# total_rev_hi_lim               -0.116228         0.024380       -0.002930
# home_rent                       0.155843        -0.039813        0.008816
# home_mortgage                  -0.160054         0.033798       -0.010147
# home_none                       0.002081        -0.004897       -0.000606
# home_other                      0.006173        -0.006035       -0.000614
# home_own                        0.014164         0.010036        0.002926
# verified                       -0.633888        -0.500335        0.003825
# not_verified                    1.000000        -0.352499       -0.002922
# source_verified                -0.352499         1.000000       -0.001358
# status_default                 -0.002922        -0.001358        1.000000
#
# [36 rows x 36 columns]

# %% [markdown]
# #The stuff below this comment is not finished. I probably won't be able to finish until Thursday.

# %%
X = defaultingdata.drop('status_default', axis = 1)
lm.fit(X, defaultingdata.status_default)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Estimated intercept coefficent:',lm.intercept_)
# Out:
# Estimated intercept coefficent: -0.0072346542811625655

# %%
print('Number of coefficients:',len(lm.coef_))
# Out:
# Number of coefficients: 35

# %%
print('R^2:', lm.score(X, defaultingdata.status_default))
# Out:
# R^2: 0.0006274808652619868
